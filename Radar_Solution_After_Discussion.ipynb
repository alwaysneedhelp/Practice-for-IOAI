# %% [markdown]
# <a href="https://colab.research.google.com/github/alwaysneedhelp/Practice-for-IOAI/blob/main/Radar_Solution_After_Discussion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.7.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !gdown https://drive.google.com/uc?id=1mXqBIqSfHif3LvJ7Jce1C7addqdfu7B-
# !unzip Millimeter-wave_dataset.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1mXqBIqSfHif3LvJ7Jce1C7addqdfu7B-
# From (redirected): https://drive.google.com/uc?id=1mXqBIqSfHif3LvJ7Jce1C7addqdfu7B-&confirm=t&uuid=46ca03ce-7ac5-4f0f-a2dc-ffe5342bd559
# To: /content/Millimeter-wave_dataset.zip
# 100% 937M/937M [00:08<00:00, 109MB/s]
# Archive:  Millimeter-wave_dataset.zip
#    creating: training_set/
#   inflating: __MACOSX/._training_set
#   inflating: training_set/1503.mat.pt
#   inflating: __MACOSX/training_set/._1503.mat.pt
#   inflating: training_set/1252.mat.pt
#   inflating: __MACOSX/training_set/._1252.mat.pt
#   inflating: training_set/1403.mat.pt
#   inflating: __MACOSX/training_set/._1403.mat.pt
#   inflating: training_set/1352.mat.pt
#   inflating: __MACOSX/training_set/._1352.mat.pt
#   inflating: training_set/1098.mat.pt
#   inflating: __MACOSX/training_set/._1098.mat.pt
#   inflating: training_set/994.mat.pt
#   inflating: __MACOSX/training_set/._994.mat.pt
#   inflating: training_set/1198.mat.pt
#   inflating: __MACOSX/training_set/._1198.mat.pt
#   inflating: training_set/894.mat.pt
#   inflating: __MACOSX/training_set/._894.mat.pt
#   inflating: training_set/267.mat.pt
#   inflating: __MACOSX/training_set/._267.mat.pt
#   inflating: training_set/536.mat.pt
#   inflating: __MACOSX/training_set/._536.mat.pt
#   inflating: training_set/91.mat.pt
#   inflating: __MACOSX/training_set/._91.mat.pt
#   inflating: training_set/781.mat.pt
#   inflating: __MACOSX/training_set/._781.mat.pt
#   inflating: training_set/367.mat.pt
#   inflating: __MACOSX/training_set/._367.mat.pt
#   inflating: training_set/436.mat.pt
#   inflating: __MACOSX/training_set/._436.mat.pt
#   inflating: training_set/681.mat.pt
#   inflating: __MACOSX/training_set/._681.mat.pt
#   inflating: training_set/204.mat.pt
#   inflating: __MACOSX/training_set/._204.mat.pt
#   inflating: training_set/555.mat.pt
#   inflating: __MACOSX/training_set/._555.mat.pt
#   inflating: training_set/304.mat.pt
#   inflating: __MACOSX/training_set/._304.mat.pt
#   inflating: training_set/455.mat.pt
#   inflating: __MACOSX/training_set/._455.mat.pt
#   inflating: training_set/279.mat.pt
#   inflating: __MACOSX/training_set/._279.mat.pt
#   inflating: training_set/528.mat.pt
#   inflating: __MACOSX/training_set/._528.mat.pt
#   inflating: training_set/379.mat.pt
#   inflating: __MACOSX/training_set/._379.mat.pt
#   inflating: training_set/428.mat.pt
#   inflating: __MACOSX/training_set/._428.mat.pt
#   inflating: training_set/1560.mat.pt
#   inflating: __MACOSX/training_set/._1560.mat.pt
#   inflating: training_set/1231.mat.pt
#   inflating: __MACOSX/training_set/._1231.mat.pt
#   inflating: training_set/1086.mat.pt
#   inflating: __MACOSX/training_set/._1086.mat.pt
#   inflating: training_set/1460.mat.pt
#   inflating: __MACOSX/training_set/._1460.mat.pt
#   inflating: training_set/1331.mat.pt
#   inflating: __MACOSX/training_set/._1331.mat.pt
#   inflating: training_set/1186.mat.pt
#   inflating: __MACOSX/training_set/._1186.mat.pt
#   inflating: training_set/1340.mat.pt
#   inflating: __MACOSX/training_set/._1340.mat.pt
#   inflating: training_set/1411.mat.pt
#   inflating: __MACOSX/training_set/._1411.mat.pt
#   inflating: training_set/1240.mat.pt
#   inflating: __MACOSX/training_set/._1240.mat.pt
#   inflating: training_set/1511.mat.pt
#   inflating: __MACOSX/training_set/._1511.mat.pt
#   inflating: training_set/459.mat.pt
#   inflating: __MACOSX/training_set/._459.mat.pt
#   inflating: training_set/308.mat.pt
#   inflating: __MACOSX/training_set/._308.mat.pt
#   inflating: training_set/559.mat.pt
#   inflating: __MACOSX/training_set/._559.mat.pt
#   inflating: training_set/208.mat.pt
#   inflating: __MACOSX/training_set/._208.mat.pt
#   inflating: training_set/886.mat.pt
#   inflating: __MACOSX/training_set/._886.mat.pt
#   inflating: training_set/986.mat.pt
#   inflating: __MACOSX/training_set/._986.mat.pt
#   inflating: training_set/693.mat.pt
#   inflating: __MACOSX/training_set/._693.mat.pt
#   inflating: training_set/424.mat.pt
#   inflating: __MACOSX/training_set/._424.mat.pt
#   inflating: training_set/375.mat.pt
#   inflating: __MACOSX/training_set/._375.mat.pt
#   inflating: training_set/793.mat.pt
#   inflating: __MACOSX/training_set/._793.mat.pt
#   inflating: training_set/83.mat.pt
#   inflating: __MACOSX/training_set/._83.mat.pt
#   inflating: training_set/524.mat.pt
#   inflating: __MACOSX/training_set/._524.mat.pt
#   inflating: training_set/275.mat.pt
#   inflating: __MACOSX/training_set/._275.mat.pt
#   inflating: training_set/447.mat.pt
#   inflating: __MACOSX/training_set/._447.mat.pt
#   inflating: training_set/316.mat.pt
#   inflating: __MACOSX/training_set/._316.mat.pt
#   inflating: training_set/547.mat.pt
#   inflating: __MACOSX/training_set/._547.mat.pt
#   inflating: training_set/216.mat.pt
#   inflating: __MACOSX/training_set/._216.mat.pt
#   inflating: training_set/1194.mat.pt
#   inflating: __MACOSX/training_set/._1194.mat.pt
#   inflating: training_set/1323.mat.pt
#   inflating: __MACOSX/training_set/._1323.mat.pt
#   inflating: training_set/898.mat.pt
#   inflating: __MACOSX/training_set/._898.mat.pt
#   inflating: training_set/1472.mat.pt
#   inflating: __MACOSX/training_set/._1472.mat.pt
#   inflating: training_set/1094.mat.pt
#   inflating: __MACOSX/training_set/._1094.mat.pt
#   inflating: training_set/1223.mat.pt
#   inflating: __MACOSX/training_set/._1223.mat.pt
#   inflating: training_set/998.mat.pt
#   inflating: __MACOSX/training_set/._998.mat.pt
#   inflating: training_set/1572.mat.pt
#   inflating: __MACOSX/training_set/._1572.mat.pt
#   inflating: training_set/189.mat.pt
#   inflating: __MACOSX/training_set/._189.mat.pt
#   inflating: training_set/1690.mat.pt
#   inflating: __MACOSX/training_set/._1690.mat.pt
#   inflating: training_set/1427.mat.pt
#   inflating: __MACOSX/training_set/._1427.mat.pt
#   inflating: training_set/1376.mat.pt
#   inflating: __MACOSX/training_set/._1376.mat.pt
#   inflating: training_set/1790.mat.pt
#   inflating: __MACOSX/training_set/._1790.mat.pt
#   inflating: training_set/1527.mat.pt
#   inflating: __MACOSX/training_set/._1527.mat.pt
#   inflating: training_set/1276.mat.pt
#   inflating: __MACOSX/training_set/._1276.mat.pt
#   inflating: training_set/343.mat.pt
#   inflating: __MACOSX/training_set/._343.mat.pt
#   inflating: training_set/412.mat.pt
#   inflating: __MACOSX/training_set/._412.mat.pt
#   inflating: training_set/243.mat.pt
#   inflating: __MACOSX/training_set/._243.mat.pt
#   inflating: training_set/512.mat.pt
#   inflating: __MACOSX/training_set/._512.mat.pt
#   inflating: training_set/1439.mat.pt
#   inflating: __MACOSX/training_set/._1439.mat.pt
#   inflating: training_set/1368.mat.pt
#   inflating: __MACOSX/training_set/._1368.mat.pt
#   inflating: training_set/1539.mat.pt
#   inflating: __MACOSX/training_set/._1539.mat.pt
#   inflating: training_set/1268.mat.pt
#   inflating: __MACOSX/training_set/._1268.mat.pt
#   inflating: training_set/197.mat.pt
#   inflating: __MACOSX/training_set/._197.mat.pt
#   inflating: training_set/320.mat.pt
#   inflating: __MACOSX/training_set/._320.mat.pt
#   inflating: training_set/471.mat.pt
#   inflating: __MACOSX/training_set/._471.mat.pt
#   inflating: training_set/220.mat.pt
#   inflating: __MACOSX/training_set/._220.mat.pt
#   inflating: training_set/571.mat.pt
#   inflating: __MACOSX/training_set/._571.mat.pt
#   inflating: training_set/1444.mat.pt
#   inflating: __MACOSX/training_set/._1444.mat.pt
#   inflating: training_set/1315.mat.pt
#   inflating: __MACOSX/training_set/._1315.mat.pt
#   inflating: training_set/1544.mat.pt
#   inflating: __MACOSX/training_set/._1544.mat.pt
#   inflating: training_set/1215.mat.pt
#   inflating: __MACOSX/training_set/._1215.mat.pt
#   inflating: training_set/1264.mat.pt
#   inflating: __MACOSX/training_set/._1264.mat.pt
#   inflating: training_set/1535.mat.pt
#   inflating: __MACOSX/training_set/._1535.mat.pt
#   inflating: training_set/1782.mat.pt
#   inflating: __MACOSX/training_set/._1782.mat.pt
#   inflating: training_set/1364.mat.pt
#   inflating: __MACOSX/training_set/._1364.mat.pt
#   inflating: training_set/1435.mat.pt
#   inflating: __MACOSX/training_set/._1435.mat.pt
#   inflating: training_set/6.mat.pt
#   inflating: __MACOSX/training_set/._6.mat.pt
#   inflating: training_set/1682.mat.pt
#   inflating: __MACOSX/training_set/._1682.mat.pt
#   inflating: training_set/500.mat.pt
#   inflating: __MACOSX/training_set/._500.mat.pt
#   inflating: training_set/251.mat.pt
#   inflating: __MACOSX/training_set/._251.mat.pt
#   inflating: training_set/400.mat.pt
#   inflating: __MACOSX/training_set/._400.mat.pt
#   inflating: training_set/351.mat.pt
#   inflating: __MACOSX/training_set/._351.mat.pt
#   inflating: training_set/1219.mat.pt
#   inflating: __MACOSX/training_set/._1219.mat.pt
#   inflating: training_set/1548.mat.pt
#   inflating: __MACOSX/training_set/._1548.mat.pt
#   inflating: training_set/1319.mat.pt
#   inflating: __MACOSX/training_set/._1319.mat.pt
#   inflating: training_set/1448.mat.pt
#   inflating: __MACOSX/training_set/._1448.mat.pt
#   inflating: training_set/563.mat.pt
#   inflating: __MACOSX/training_set/._563.mat.pt
#   inflating: training_set/232.mat.pt
#   inflating: __MACOSX/training_set/._232.mat.pt
#   inflating: training_set/463.mat.pt
#   inflating: __MACOSX/training_set/._463.mat.pt
#   inflating: training_set/332.mat.pt
#   inflating: __MACOSX/training_set/._332.mat.pt
#   inflating: training_set/185.mat.pt
#   inflating: __MACOSX/training_set/._185.mat.pt
#   inflating: training_set/1207.mat.pt
#   inflating: __MACOSX/training_set/._1207.mat.pt
#   inflating: training_set/1556.mat.pt
#   inflating: __MACOSX/training_set/._1556.mat.pt
#   inflating: training_set/1307.mat.pt
#   inflating: __MACOSX/training_set/._1307.mat.pt
#   inflating: training_set/1456.mat.pt
#   inflating: __MACOSX/training_set/._1456.mat.pt
#   inflating: training_set/1581.mat.pt
#   inflating: __MACOSX/training_set/._1581.mat.pt
#   inflating: training_set/1067.mat.pt
#   inflating: __MACOSX/training_set/._1067.mat.pt
#   inflating: training_set/1736.mat.pt
#   inflating: __MACOSX/training_set/._1736.mat.pt
#   inflating: training_set/1481.mat.pt
#   inflating: __MACOSX/training_set/._1481.mat.pt
#   inflating: training_set/1167.mat.pt
#   inflating: __MACOSX/training_set/._1167.mat.pt
#   inflating: training_set/1636.mat.pt
#   inflating: __MACOSX/training_set/._1636.mat.pt
#   inflating: training_set/298.mat.pt
#   inflating: __MACOSX/training_set/._298.mat.pt
#   inflating: training_set/398.mat.pt
#   inflating: __MACOSX/training_set/._398.mat.pt
#   inflating: training_set/916.mat.pt
#   inflating: __MACOSX/training_set/._916.mat.pt
#   inflating: training_set/816.mat.pt
#   inflating: __MACOSX/training_set/._816.mat.pt
#   inflating: training_set/703.mat.pt
#   inflating: __MACOSX/training_set/._703.mat.pt
#   inflating: training_set/13.mat.pt
#   inflating: __MACOSX/training_set/._13.mat.pt
#   inflating: training_set/603.mat.pt
#   inflating: __MACOSX/training_set/._603.mat.pt
#   inflating: training_set/152.mat.pt
#   inflating: __MACOSX/training_set/._152.mat.pt
#   inflating: training_set/286.mat.pt
#   inflating: __MACOSX/training_set/._286.mat.pt
#   inflating: training_set/760.mat.pt
#   inflating: __MACOSX/training_set/._760.mat.pt
#   inflating: training_set/70.mat.pt
#   inflating: __MACOSX/training_set/._70.mat.pt
#   inflating: training_set/386.mat.pt
#   inflating: __MACOSX/training_set/._386.mat.pt
#   inflating: training_set/660.mat.pt
#   inflating: __MACOSX/training_set/._660.mat.pt
#   inflating: training_set/131.mat.pt
#   inflating: __MACOSX/training_set/._131.mat.pt
#   inflating: training_set/1079.mat.pt
#   inflating: __MACOSX/training_set/._1079.mat.pt
#   inflating: training_set/1728.mat.pt
#   inflating: __MACOSX/training_set/._1728.mat.pt
#   inflating: training_set/975.mat.pt
#   inflating: __MACOSX/training_set/._975.mat.pt
#   inflating: training_set/1179.mat.pt
#   inflating: __MACOSX/training_set/._1179.mat.pt
#   inflating: training_set/1628.mat.pt
#   inflating: __MACOSX/training_set/._1628.mat.pt
#   inflating: training_set/875.mat.pt
#   inflating: __MACOSX/training_set/._875.mat.pt
#   inflating: training_set/1004.mat.pt
#   inflating: __MACOSX/training_set/._1004.mat.pt
#   inflating: training_set/1755.mat.pt
#   inflating: __MACOSX/training_set/._1755.mat.pt
#   inflating: training_set/908.mat.pt
#   inflating: __MACOSX/training_set/._908.mat.pt
#   inflating: training_set/1104.mat.pt
#   inflating: __MACOSX/training_set/._1104.mat.pt
#   inflating: training_set/1655.mat.pt
#   inflating: __MACOSX/training_set/._1655.mat.pt
#   inflating: training_set/808.mat.pt
#   inflating: __MACOSX/training_set/._808.mat.pt
#   inflating: training_set/1624.mat.pt
#   inflating: __MACOSX/training_set/._1624.mat.pt
#   inflating: training_set/1175.mat.pt
#   inflating: __MACOSX/training_set/._1175.mat.pt
#   inflating: training_set/1493.mat.pt
#   inflating: __MACOSX/training_set/._1493.mat.pt
#   inflating: training_set/879.mat.pt
#   inflating: __MACOSX/training_set/._879.mat.pt
#   inflating: training_set/1724.mat.pt
#   inflating: __MACOSX/training_set/._1724.mat.pt
#   inflating: training_set/1075.mat.pt
#   inflating: __MACOSX/training_set/._1075.mat.pt
#   inflating: training_set/1593.mat.pt
#   inflating: __MACOSX/training_set/._1593.mat.pt
#   inflating: training_set/979.mat.pt
#   inflating: __MACOSX/training_set/._979.mat.pt
#   inflating: training_set/1659.mat.pt
#   inflating: __MACOSX/training_set/._1659.mat.pt
#   inflating: training_set/1108.mat.pt
#   inflating: __MACOSX/training_set/._1108.mat.pt
#   inflating: training_set/804.mat.pt
#   inflating: __MACOSX/training_set/._804.mat.pt
#   inflating: training_set/1759.mat.pt
#   inflating: __MACOSX/training_set/._1759.mat.pt
#   inflating: training_set/1008.mat.pt
#   inflating: __MACOSX/training_set/._1008.mat.pt
#   inflating: training_set/904.mat.pt
#   inflating: __MACOSX/training_set/._904.mat.pt
#   inflating: training_set/140.mat.pt
#   inflating: __MACOSX/training_set/._140.mat.pt
#   inflating: training_set/611.mat.pt
#   inflating: __MACOSX/training_set/._611.mat.pt
#   inflating: training_set/711.mat.pt
#   inflating: __MACOSX/training_set/._711.mat.pt
#   inflating: training_set/123.mat.pt
#   inflating: __MACOSX/training_set/._123.mat.pt
#   inflating: training_set/672.mat.pt
#   inflating: __MACOSX/training_set/._672.mat.pt
#   inflating: training_set/394.mat.pt
#   inflating: __MACOSX/training_set/._394.mat.pt
#   inflating: training_set/62.mat.pt
#   inflating: __MACOSX/training_set/._62.mat.pt
#   inflating: training_set/772.mat.pt
#   inflating: __MACOSX/training_set/._772.mat.pt
#   inflating: training_set/294.mat.pt
#   inflating: __MACOSX/training_set/._294.mat.pt
#   inflating: training_set/867.mat.pt
#   inflating: __MACOSX/training_set/._867.mat.pt
#   inflating: training_set/967.mat.pt
#   inflating: __MACOSX/training_set/._967.mat.pt
#   inflating: training_set/1647.mat.pt
#   inflating: __MACOSX/training_set/._1647.mat.pt
#   inflating: training_set/1116.mat.pt
#   inflating: __MACOSX/training_set/._1116.mat.pt
#   inflating: training_set/1747.mat.pt
#   inflating: __MACOSX/training_set/._1747.mat.pt
#   inflating: training_set/1016.mat.pt
#   inflating: __MACOSX/training_set/._1016.mat.pt
#   inflating: training_set/1143.mat.pt
#   inflating: __MACOSX/training_set/._1143.mat.pt
#   inflating: training_set/1612.mat.pt
#   inflating: __MACOSX/training_set/._1612.mat.pt
#   inflating: training_set/1043.mat.pt
#   inflating: __MACOSX/training_set/._1043.mat.pt
#   inflating: training_set/1712.mat.pt
#   inflating: __MACOSX/training_set/._1712.mat.pt
#   inflating: training_set/627.mat.pt
#   inflating: __MACOSX/training_set/._627.mat.pt
#   inflating: training_set/176.mat.pt
#   inflating: __MACOSX/training_set/._176.mat.pt
#   inflating: training_set/490.mat.pt
#   inflating: __MACOSX/training_set/._490.mat.pt
#   inflating: training_set/727.mat.pt
#   inflating: __MACOSX/training_set/._727.mat.pt
#   inflating: training_set/37.mat.pt
#   inflating: __MACOSX/training_set/._37.mat.pt
#   inflating: training_set/590.mat.pt
#   inflating: __MACOSX/training_set/._590.mat.pt
#   inflating: training_set/832.mat.pt
#   inflating: __MACOSX/training_set/._832.mat.pt
#   inflating: training_set/1389.mat.pt
#   inflating: __MACOSX/training_set/._1389.mat.pt
#   inflating: training_set/932.mat.pt
#   inflating: __MACOSX/training_set/._932.mat.pt
#   inflating: training_set/1289.mat.pt
#   inflating: __MACOSX/training_set/._1289.mat.pt
#   inflating: training_set/851.mat.pt
#   inflating: __MACOSX/training_set/._851.mat.pt
#   inflating: training_set/951.mat.pt
#   inflating: __MACOSX/training_set/._951.mat.pt
#   inflating: training_set/644.mat.pt
#   inflating: __MACOSX/training_set/._644.mat.pt
#   inflating: training_set/115.mat.pt
#   inflating: __MACOSX/training_set/._115.mat.pt
#   inflating: training_set/744.mat.pt
#   inflating: __MACOSX/training_set/._744.mat.pt
#   inflating: training_set/54.mat.pt
#   inflating: __MACOSX/training_set/._54.mat.pt
#   inflating: training_set/1120.mat.pt
#   inflating: __MACOSX/training_set/._1120.mat.pt
#   inflating: training_set/1671.mat.pt
#   inflating: __MACOSX/training_set/._1671.mat.pt
#   inflating: training_set/1397.mat.pt
#   inflating: __MACOSX/training_set/._1397.mat.pt
#   inflating: training_set/1020.mat.pt
#   inflating: __MACOSX/training_set/._1020.mat.pt
#   inflating: training_set/1771.mat.pt
#   inflating: __MACOSX/training_set/._1771.mat.pt
#   inflating: training_set/1297.mat.pt
#   inflating: __MACOSX/training_set/._1297.mat.pt
#   inflating: training_set/639.mat.pt
#   inflating: __MACOSX/training_set/._639.mat.pt
#   inflating: training_set/168.mat.pt
#   inflating: __MACOSX/training_set/._168.mat.pt
#   inflating: training_set/739.mat.pt
#   inflating: __MACOSX/training_set/._739.mat.pt
#   inflating: training_set/29.mat.pt
#   inflating: __MACOSX/training_set/._29.mat.pt
#   inflating: training_set/58.mat.pt
#   inflating: __MACOSX/training_set/._58.mat.pt
#   inflating: training_set/748.mat.pt
#   inflating: __MACOSX/training_set/._748.mat.pt
#   inflating: training_set/119.mat.pt
#   inflating: __MACOSX/training_set/._119.mat.pt
#   inflating: training_set/648.mat.pt
#   inflating: __MACOSX/training_set/._648.mat.pt
#   inflating: training_set/1700.mat.pt
#   inflating: __MACOSX/training_set/._1700.mat.pt
#   inflating: training_set/1051.mat.pt
#   inflating: __MACOSX/training_set/._1051.mat.pt
#   inflating: training_set/1600.mat.pt
#   inflating: __MACOSX/training_set/._1600.mat.pt
#   inflating: training_set/1151.mat.pt
#   inflating: __MACOSX/training_set/._1151.mat.pt
#   inflating: training_set/582.mat.pt
#   inflating: __MACOSX/training_set/._582.mat.pt
#   inflating: training_set/25.mat.pt
#   inflating: __MACOSX/training_set/._25.mat.pt
#   inflating: training_set/735.mat.pt
#   inflating: __MACOSX/training_set/._735.mat.pt
#   inflating: training_set/482.mat.pt
#   inflating: __MACOSX/training_set/._482.mat.pt
#   inflating: training_set/164.mat.pt
#   inflating: __MACOSX/training_set/._164.mat.pt
#   inflating: training_set/635.mat.pt
#   inflating: __MACOSX/training_set/._635.mat.pt
#   inflating: training_set/920.mat.pt
#   inflating: __MACOSX/training_set/._920.mat.pt
#   inflating: training_set/820.mat.pt
#   inflating: __MACOSX/training_set/._820.mat.pt
#   inflating: training_set/943.mat.pt
#   inflating: __MACOSX/training_set/._943.mat.pt
#   inflating: training_set/843.mat.pt
#   inflating: __MACOSX/training_set/._843.mat.pt
#   inflating: training_set/46.mat.pt
#   inflating: __MACOSX/training_set/._46.mat.pt
#   inflating: training_set/756.mat.pt
#   inflating: __MACOSX/training_set/._756.mat.pt
#   inflating: training_set/107.mat.pt
#   inflating: __MACOSX/training_set/._107.mat.pt
#   inflating: training_set/656.mat.pt
#   inflating: __MACOSX/training_set/._656.mat.pt
#   inflating: training_set/1285.mat.pt
#   inflating: __MACOSX/training_set/._1285.mat.pt
#   inflating: training_set/1763.mat.pt
#   inflating: __MACOSX/training_set/._1763.mat.pt
#   inflating: training_set/1032.mat.pt
#   inflating: __MACOSX/training_set/._1032.mat.pt
#   inflating: training_set/1385.mat.pt
#   inflating: __MACOSX/training_set/._1385.mat.pt
#   inflating: training_set/1663.mat.pt
#   inflating: __MACOSX/training_set/._1663.mat.pt
#   inflating: training_set/1132.mat.pt
#   inflating: __MACOSX/training_set/._1132.mat.pt
#   inflating: training_set/865.mat.pt
#   inflating: __MACOSX/training_set/._865.mat.pt
#   inflating: training_set/1638.mat.pt
#   inflating: __MACOSX/training_set/._1638.mat.pt
#   inflating: training_set/1169.mat.pt
#   inflating: __MACOSX/training_set/._1169.mat.pt
#   inflating: training_set/965.mat.pt
#   inflating: __MACOSX/training_set/._965.mat.pt
#   inflating: training_set/1738.mat.pt
#   inflating: __MACOSX/training_set/._1738.mat.pt
#   inflating: training_set/1069.mat.pt
#   inflating: __MACOSX/training_set/._1069.mat.pt
#   inflating: training_set/121.mat.pt
#   inflating: __MACOSX/training_set/._121.mat.pt
#   inflating: training_set/670.mat.pt
#   inflating: __MACOSX/training_set/._670.mat.pt
#   inflating: training_set/396.mat.pt
#   inflating: __MACOSX/training_set/._396.mat.pt
#   inflating: training_set/60.mat.pt
#   inflating: __MACOSX/training_set/._60.mat.pt
#   inflating: training_set/770.mat.pt
#   inflating: __MACOSX/training_set/._770.mat.pt
#   inflating: training_set/296.mat.pt
#   inflating: __MACOSX/training_set/._296.mat.pt
#   inflating: training_set/818.mat.pt
#   inflating: __MACOSX/training_set/._818.mat.pt
#   inflating: training_set/1645.mat.pt
#   inflating: __MACOSX/training_set/._1645.mat.pt
#   inflating: training_set/1114.mat.pt
#   inflating: __MACOSX/training_set/._1114.mat.pt
#   inflating: training_set/918.mat.pt
#   inflating: __MACOSX/training_set/._918.mat.pt
#   inflating: training_set/1745.mat.pt
#   inflating: __MACOSX/training_set/._1745.mat.pt
#   inflating: training_set/1014.mat.pt
#   inflating: __MACOSX/training_set/._1014.mat.pt
#   inflating: training_set/388.mat.pt
#   inflating: __MACOSX/training_set/._388.mat.pt
#   inflating: training_set/288.mat.pt
#   inflating: __MACOSX/training_set/._288.mat.pt
#   inflating: training_set/1626.mat.pt
#   inflating: __MACOSX/training_set/._1626.mat.pt
#   inflating: training_set/1177.mat.pt
#   inflating: __MACOSX/training_set/._1177.mat.pt
#   inflating: training_set/1491.mat.pt
#   inflating: __MACOSX/training_set/._1491.mat.pt
#   inflating: training_set/1726.mat.pt
#   inflating: __MACOSX/training_set/._1726.mat.pt
#   inflating: training_set/1077.mat.pt
#   inflating: __MACOSX/training_set/._1077.mat.pt
#   inflating: training_set/1591.mat.pt
#   inflating: __MACOSX/training_set/._1591.mat.pt
#   inflating: training_set/142.mat.pt
#   inflating: __MACOSX/training_set/._142.mat.pt
#   inflating: training_set/613.mat.pt
#   inflating: __MACOSX/training_set/._613.mat.pt
#   inflating: training_set/713.mat.pt
#   inflating: __MACOSX/training_set/._713.mat.pt
#   inflating: training_set/806.mat.pt
#   inflating: __MACOSX/training_set/._806.mat.pt
#   inflating: training_set/906.mat.pt
#   inflating: __MACOSX/training_set/._906.mat.pt
#   inflating: training_set/977.mat.pt
#   inflating: __MACOSX/training_set/._977.mat.pt
#   inflating: training_set/877.mat.pt
#   inflating: __MACOSX/training_set/._877.mat.pt
#   inflating: training_set/284.mat.pt
#   inflating: __MACOSX/training_set/._284.mat.pt
#   inflating: training_set/762.mat.pt
#   inflating: __MACOSX/training_set/._762.mat.pt
#   inflating: training_set/72.mat.pt
#   inflating: __MACOSX/training_set/._72.mat.pt
#   inflating: training_set/384.mat.pt
#   inflating: __MACOSX/training_set/._384.mat.pt
#   inflating: training_set/662.mat.pt
#   inflating: __MACOSX/training_set/._662.mat.pt
#   inflating: training_set/133.mat.pt
#   inflating: __MACOSX/training_set/._133.mat.pt
#   inflating: training_set/1006.mat.pt
#   inflating: __MACOSX/training_set/._1006.mat.pt
#   inflating: training_set/1757.mat.pt
#   inflating: __MACOSX/training_set/._1757.mat.pt
#   inflating: training_set/1106.mat.pt
#   inflating: __MACOSX/training_set/._1106.mat.pt
#   inflating: training_set/1657.mat.pt
#   inflating: __MACOSX/training_set/._1657.mat.pt
#   inflating: training_set/969.mat.pt
#   inflating: __MACOSX/training_set/._969.mat.pt
#   inflating: training_set/1583.mat.pt
#   inflating: __MACOSX/training_set/._1583.mat.pt
#   inflating: training_set/1065.mat.pt
#   inflating: __MACOSX/training_set/._1065.mat.pt
#   inflating: training_set/1734.mat.pt
#   inflating: __MACOSX/training_set/._1734.mat.pt
#   inflating: training_set/869.mat.pt
#   inflating: __MACOSX/training_set/._869.mat.pt
#   inflating: training_set/1483.mat.pt
#   inflating: __MACOSX/training_set/._1483.mat.pt
#   inflating: training_set/1165.mat.pt
#   inflating: __MACOSX/training_set/._1165.mat.pt
#   inflating: training_set/1634.mat.pt
#   inflating: __MACOSX/training_set/._1634.mat.pt
#   inflating: training_set/701.mat.pt
#   inflating: __MACOSX/training_set/._701.mat.pt
#   inflating: training_set/11.mat.pt
#   inflating: __MACOSX/training_set/._11.mat.pt
#   inflating: training_set/601.mat.pt
#   inflating: __MACOSX/training_set/._601.mat.pt
#   inflating: training_set/150.mat.pt
#   inflating: __MACOSX/training_set/._150.mat.pt
#   inflating: training_set/914.mat.pt
#   inflating: __MACOSX/training_set/._914.mat.pt
#   inflating: training_set/1018.mat.pt
#   inflating: __MACOSX/training_set/._1018.mat.pt
#   inflating: training_set/1749.mat.pt
#   inflating: __MACOSX/training_set/._1749.mat.pt
#   inflating: training_set/814.mat.pt
#   inflating: __MACOSX/training_set/._814.mat.pt
#   inflating: training_set/1118.mat.pt
#   inflating: __MACOSX/training_set/._1118.mat.pt
#   inflating: training_set/1649.mat.pt
#   inflating: __MACOSX/training_set/._1649.mat.pt
#   inflating: training_set/44.mat.pt
#   inflating: __MACOSX/training_set/._44.mat.pt
#   inflating: training_set/754.mat.pt
#   inflating: __MACOSX/training_set/._754.mat.pt
#   inflating: training_set/105.mat.pt
#   inflating: __MACOSX/training_set/._105.mat.pt
#   inflating: training_set/654.mat.pt
#   inflating: __MACOSX/training_set/._654.mat.pt
#   inflating: training_set/941.mat.pt
#   inflating: __MACOSX/training_set/._941.mat.pt
#   inflating: training_set/841.mat.pt
#   inflating: __MACOSX/training_set/._841.mat.pt
#   inflating: training_set/39.mat.pt
#   inflating: __MACOSX/training_set/._39.mat.pt
#   inflating: training_set/729.mat.pt
#   inflating: __MACOSX/training_set/._729.mat.pt
#   inflating: training_set/178.mat.pt
#   inflating: __MACOSX/training_set/._178.mat.pt
#   inflating: training_set/629.mat.pt
#   inflating: __MACOSX/training_set/._629.mat.pt
#   inflating: training_set/1287.mat.pt
#   inflating: __MACOSX/training_set/._1287.mat.pt
#   inflating: training_set/1761.mat.pt
#   inflating: __MACOSX/training_set/._1761.mat.pt
#   inflating: training_set/1030.mat.pt
#   inflating: __MACOSX/training_set/._1030.mat.pt
#   inflating: training_set/1387.mat.pt
#   inflating: __MACOSX/training_set/._1387.mat.pt
#   inflating: training_set/1661.mat.pt
#   inflating: __MACOSX/training_set/._1661.mat.pt
#   inflating: training_set/1130.mat.pt
#   inflating: __MACOSX/training_set/._1130.mat.pt
#   inflating: training_set/1702.mat.pt
#   inflating: __MACOSX/training_set/._1702.mat.pt
#   inflating: training_set/1053.mat.pt
#   inflating: __MACOSX/training_set/._1053.mat.pt
#   inflating: training_set/1602.mat.pt
#   inflating: __MACOSX/training_set/._1602.mat.pt
#   inflating: training_set/1153.mat.pt
#   inflating: __MACOSX/training_set/._1153.mat.pt
#   inflating: training_set/1299.mat.pt
#   inflating: __MACOSX/training_set/._1299.mat.pt
#   inflating: training_set/922.mat.pt
#   inflating: __MACOSX/training_set/._922.mat.pt
#   inflating: training_set/1399.mat.pt
#   inflating: __MACOSX/training_set/._1399.mat.pt
#   inflating: training_set/822.mat.pt
#   inflating: __MACOSX/training_set/._822.mat.pt
#   inflating: training_set/580.mat.pt
#   inflating: __MACOSX/training_set/._580.mat.pt
#   inflating: training_set/27.mat.pt
#   inflating: __MACOSX/training_set/._27.mat.pt
#   inflating: training_set/737.mat.pt
#   inflating: __MACOSX/training_set/._737.mat.pt
#   inflating: training_set/480.mat.pt
#   inflating: __MACOSX/training_set/._480.mat.pt
#   inflating: training_set/166.mat.pt
#   inflating: __MACOSX/training_set/._166.mat.pt
#   inflating: training_set/637.mat.pt
#   inflating: __MACOSX/training_set/._637.mat.pt
#   inflating: training_set/646.mat.pt
#   inflating: __MACOSX/training_set/._646.mat.pt
#   inflating: training_set/117.mat.pt
#   inflating: __MACOSX/training_set/._117.mat.pt
#   inflating: training_set/746.mat.pt
#   inflating: __MACOSX/training_set/._746.mat.pt
#   inflating: training_set/56.mat.pt
#   inflating: __MACOSX/training_set/._56.mat.pt
#   inflating: training_set/853.mat.pt
#   inflating: __MACOSX/training_set/._853.mat.pt
#   inflating: training_set/953.mat.pt
#   inflating: __MACOSX/training_set/._953.mat.pt
#   inflating: training_set/1122.mat.pt
#   inflating: __MACOSX/training_set/._1122.mat.pt
#   inflating: training_set/1673.mat.pt
#   inflating: __MACOSX/training_set/._1673.mat.pt
#   inflating: training_set/1395.mat.pt
#   inflating: __MACOSX/training_set/._1395.mat.pt
#   inflating: training_set/1022.mat.pt
#   inflating: __MACOSX/training_set/._1022.mat.pt
#   inflating: training_set/1773.mat.pt
#   inflating: __MACOSX/training_set/._1773.mat.pt
#   inflating: training_set/1295.mat.pt
#   inflating: __MACOSX/training_set/._1295.mat.pt
#   inflating: training_set/1141.mat.pt
#   inflating: __MACOSX/training_set/._1141.mat.pt
#   inflating: training_set/1610.mat.pt
#   inflating: __MACOSX/training_set/._1610.mat.pt
#   inflating: training_set/1041.mat.pt
#   inflating: __MACOSX/training_set/._1041.mat.pt
#   inflating: training_set/1710.mat.pt
#   inflating: __MACOSX/training_set/._1710.mat.pt
#   inflating: training_set/658.mat.pt
#   inflating: __MACOSX/training_set/._658.mat.pt
#   inflating: training_set/109.mat.pt
#   inflating: __MACOSX/training_set/._109.mat.pt
#   inflating: training_set/758.mat.pt
#   inflating: __MACOSX/training_set/._758.mat.pt
#   inflating: training_set/48.mat.pt
#   inflating: __MACOSX/training_set/._48.mat.pt
#   inflating: training_set/830.mat.pt
#   inflating: __MACOSX/training_set/._830.mat.pt
#   inflating: training_set/930.mat.pt
#   inflating: __MACOSX/training_set/._930.mat.pt
#   inflating: training_set/625.mat.pt
#   inflating: __MACOSX/training_set/._625.mat.pt
#   inflating: training_set/174.mat.pt
#   inflating: __MACOSX/training_set/._174.mat.pt
#   inflating: training_set/492.mat.pt
#   inflating: __MACOSX/training_set/._492.mat.pt
#   inflating: training_set/725.mat.pt
#   inflating: __MACOSX/training_set/._725.mat.pt
#   inflating: training_set/35.mat.pt
#   inflating: __MACOSX/training_set/._35.mat.pt
#   inflating: training_set/592.mat.pt
#   inflating: __MACOSX/training_set/._592.mat.pt
#   inflating: training_set/445.mat.pt
#   inflating: __MACOSX/training_set/._445.mat.pt
#   inflating: training_set/314.mat.pt
#   inflating: __MACOSX/training_set/._314.mat.pt
#   inflating: training_set/545.mat.pt
#   inflating: __MACOSX/training_set/._545.mat.pt
#   inflating: training_set/214.mat.pt
#   inflating: __MACOSX/training_set/._214.mat.pt
#   inflating: training_set/1196.mat.pt
#   inflating: __MACOSX/training_set/._1196.mat.pt
#   inflating: training_set/1321.mat.pt
#   inflating: __MACOSX/training_set/._1321.mat.pt
#   inflating: training_set/1470.mat.pt
#   inflating: __MACOSX/training_set/._1470.mat.pt
#   inflating: training_set/1096.mat.pt
#   inflating: __MACOSX/training_set/._1096.mat.pt
#   inflating: training_set/1221.mat.pt
#   inflating: __MACOSX/training_set/._1221.mat.pt
#   inflating: training_set/1570.mat.pt
#   inflating: __MACOSX/training_set/._1570.mat.pt
#   inflating: training_set/438.mat.pt
#   inflating: __MACOSX/training_set/._438.mat.pt
#   inflating: training_set/369.mat.pt
#   inflating: __MACOSX/training_set/._369.mat.pt
#   inflating: training_set/538.mat.pt
#   inflating: __MACOSX/training_set/._538.mat.pt
#   inflating: training_set/269.mat.pt
#   inflating: __MACOSX/training_set/._269.mat.pt
#   inflating: training_set/1342.mat.pt
#   inflating: __MACOSX/training_set/._1342.mat.pt
#   inflating: training_set/1413.mat.pt
#   inflating: __MACOSX/training_set/._1413.mat.pt
#   inflating: training_set/1242.mat.pt
#   inflating: __MACOSX/training_set/._1242.mat.pt
#   inflating: training_set/1513.mat.pt
#   inflating: __MACOSX/training_set/._1513.mat.pt
#   inflating: training_set/691.mat.pt
#   inflating: __MACOSX/training_set/._691.mat.pt
#   inflating: training_set/426.mat.pt
#   inflating: __MACOSX/training_set/._426.mat.pt
#   inflating: training_set/377.mat.pt
#   inflating: __MACOSX/training_set/._377.mat.pt
#   inflating: training_set/791.mat.pt
#   inflating: __MACOSX/training_set/._791.mat.pt
#   inflating: training_set/81.mat.pt
#   inflating: __MACOSX/training_set/._81.mat.pt
#   inflating: training_set/526.mat.pt
#   inflating: __MACOSX/training_set/._526.mat.pt
#   inflating: training_set/277.mat.pt
#   inflating: __MACOSX/training_set/._277.mat.pt
#   inflating: training_set/884.mat.pt
#   inflating: __MACOSX/training_set/._884.mat.pt
#   inflating: training_set/1188.mat.pt
#   inflating: __MACOSX/training_set/._1188.mat.pt
#   inflating: training_set/984.mat.pt
#   inflating: __MACOSX/training_set/._984.mat.pt
#   inflating: training_set/1088.mat.pt
#   inflating: __MACOSX/training_set/._1088.mat.pt
#   inflating: training_set/206.mat.pt
#   inflating: __MACOSX/training_set/._206.mat.pt
#   inflating: training_set/557.mat.pt
#   inflating: __MACOSX/training_set/._557.mat.pt
#   inflating: training_set/306.mat.pt
#   inflating: __MACOSX/training_set/._306.mat.pt
#   inflating: training_set/457.mat.pt
#   inflating: __MACOSX/training_set/._457.mat.pt
#   inflating: training_set/1562.mat.pt
#   inflating: __MACOSX/training_set/._1562.mat.pt
#   inflating: training_set/988.mat.pt
#   inflating: __MACOSX/training_set/._988.mat.pt
#   inflating: training_set/1233.mat.pt
#   inflating: __MACOSX/training_set/._1233.mat.pt
#   inflating: training_set/1084.mat.pt
#   inflating: __MACOSX/training_set/._1084.mat.pt
#   inflating: training_set/1462.mat.pt
#   inflating: __MACOSX/training_set/._1462.mat.pt
#   inflating: training_set/888.mat.pt
#   inflating: __MACOSX/training_set/._888.mat.pt
#   inflating: training_set/1333.mat.pt
#   inflating: __MACOSX/training_set/._1333.mat.pt
#   inflating: training_set/1184.mat.pt
#   inflating: __MACOSX/training_set/._1184.mat.pt
#   inflating: training_set/218.mat.pt
#   inflating: __MACOSX/training_set/._218.mat.pt
#   inflating: training_set/549.mat.pt
#   inflating: __MACOSX/training_set/._549.mat.pt
#   inflating: training_set/318.mat.pt
#   inflating: __MACOSX/training_set/._318.mat.pt
#   inflating: training_set/449.mat.pt
#   inflating: __MACOSX/training_set/._449.mat.pt
#   inflating: training_set/1501.mat.pt
#   inflating: __MACOSX/training_set/._1501.mat.pt
#   inflating: training_set/1250.mat.pt
#   inflating: __MACOSX/training_set/._1250.mat.pt
#   inflating: training_set/1401.mat.pt
#   inflating: __MACOSX/training_set/._1401.mat.pt
#   inflating: training_set/1350.mat.pt
#   inflating: __MACOSX/training_set/._1350.mat.pt
#   inflating: training_set/265.mat.pt
#   inflating: __MACOSX/training_set/._265.mat.pt
#   inflating: training_set/534.mat.pt
#   inflating: __MACOSX/training_set/._534.mat.pt
#   inflating: training_set/93.mat.pt
#   inflating: __MACOSX/training_set/._93.mat.pt
#   inflating: training_set/783.mat.pt
#   inflating: __MACOSX/training_set/._783.mat.pt
#   inflating: training_set/365.mat.pt
#   inflating: __MACOSX/training_set/._365.mat.pt
#   inflating: training_set/434.mat.pt
#   inflating: __MACOSX/training_set/._434.mat.pt
#   inflating: training_set/683.mat.pt
#   inflating: __MACOSX/training_set/._683.mat.pt
#   inflating: training_set/996.mat.pt
#   inflating: __MACOSX/training_set/._996.mat.pt
#   inflating: training_set/896.mat.pt
#   inflating: __MACOSX/training_set/._896.mat.pt
#   inflating: training_set/561.mat.pt
#   inflating: __MACOSX/training_set/._561.mat.pt
#   inflating: training_set/230.mat.pt
#   inflating: __MACOSX/training_set/._230.mat.pt
#   inflating: training_set/461.mat.pt
#   inflating: __MACOSX/training_set/._461.mat.pt
#   inflating: training_set/330.mat.pt
#   inflating: __MACOSX/training_set/._330.mat.pt
#   inflating: training_set/187.mat.pt
#   inflating: __MACOSX/training_set/._187.mat.pt
#   inflating: training_set/1278.mat.pt
#   inflating: __MACOSX/training_set/._1278.mat.pt
#   inflating: training_set/1529.mat.pt
#   inflating: __MACOSX/training_set/._1529.mat.pt
#   inflating: training_set/1378.mat.pt
#   inflating: __MACOSX/training_set/._1378.mat.pt
#   inflating: training_set/1429.mat.pt
#   inflating: __MACOSX/training_set/._1429.mat.pt
#   inflating: training_set/1205.mat.pt
#   inflating: __MACOSX/training_set/._1205.mat.pt
#   inflating: training_set/1554.mat.pt
#   inflating: __MACOSX/training_set/._1554.mat.pt
#   inflating: training_set/1305.mat.pt
#   inflating: __MACOSX/training_set/._1305.mat.pt
#   inflating: training_set/1454.mat.pt
#   inflating: __MACOSX/training_set/._1454.mat.pt
#   inflating: training_set/1266.mat.pt
#   inflating: __MACOSX/training_set/._1266.mat.pt
#   inflating: training_set/1537.mat.pt
#   inflating: __MACOSX/training_set/._1537.mat.pt
#   inflating: training_set/1780.mat.pt
#   inflating: __MACOSX/training_set/._1780.mat.pt
#   inflating: training_set/1366.mat.pt
#   inflating: __MACOSX/training_set/._1366.mat.pt
#   inflating: training_set/1437.mat.pt
#   inflating: __MACOSX/training_set/._1437.mat.pt
#   inflating: training_set/4.mat.pt
#   inflating: __MACOSX/training_set/._4.mat.pt
#   inflating: training_set/1680.mat.pt
#   inflating: __MACOSX/training_set/._1680.mat.pt
#   inflating: training_set/199.mat.pt
#   inflating: __MACOSX/training_set/._199.mat.pt
#   inflating: training_set/502.mat.pt
#   inflating: __MACOSX/training_set/._502.mat.pt
#   inflating: training_set/253.mat.pt
#   inflating: __MACOSX/training_set/._253.mat.pt
#   inflating: training_set/402.mat.pt
#   inflating: __MACOSX/training_set/._402.mat.pt
#   inflating: training_set/353.mat.pt
#   inflating: __MACOSX/training_set/._353.mat.pt
#   inflating: training_set/195.mat.pt
#   inflating: __MACOSX/training_set/._195.mat.pt
#   inflating: training_set/322.mat.pt
#   inflating: __MACOSX/training_set/._322.mat.pt
#   inflating: training_set/473.mat.pt
#   inflating: __MACOSX/training_set/._473.mat.pt
#   inflating: training_set/222.mat.pt
#   inflating: __MACOSX/training_set/._222.mat.pt
#   inflating: training_set/573.mat.pt
#   inflating: __MACOSX/training_set/._573.mat.pt
#   inflating: training_set/8.mat.pt
#   inflating: __MACOSX/training_set/._8.mat.pt
#   inflating: training_set/1446.mat.pt
#   inflating: __MACOSX/training_set/._1446.mat.pt
#   inflating: training_set/1317.mat.pt
#   inflating: __MACOSX/training_set/._1317.mat.pt
#   inflating: training_set/1546.mat.pt
#   inflating: __MACOSX/training_set/._1546.mat.pt
#   inflating: training_set/1217.mat.pt
#   inflating: __MACOSX/training_set/._1217.mat.pt
#   inflating: training_set/1692.mat.pt
#   inflating: __MACOSX/training_set/._1692.mat.pt
#   inflating: training_set/1425.mat.pt
#   inflating: __MACOSX/training_set/._1425.mat.pt
#   inflating: training_set/1374.mat.pt
#   inflating: __MACOSX/training_set/._1374.mat.pt
#   inflating: training_set/1792.mat.pt
#   inflating: __MACOSX/training_set/._1792.mat.pt
#   inflating: training_set/1525.mat.pt
#   inflating: __MACOSX/training_set/._1525.mat.pt
#   inflating: training_set/1274.mat.pt
#   inflating: __MACOSX/training_set/._1274.mat.pt
#   inflating: training_set/1458.mat.pt
#   inflating: __MACOSX/training_set/._1458.mat.pt
#   inflating: training_set/1309.mat.pt
#   inflating: __MACOSX/training_set/._1309.mat.pt
#   inflating: training_set/1558.mat.pt
#   inflating: __MACOSX/training_set/._1558.mat.pt
#   inflating: training_set/1209.mat.pt
#   inflating: __MACOSX/training_set/._1209.mat.pt
#   inflating: training_set/341.mat.pt
#   inflating: __MACOSX/training_set/._341.mat.pt
#   inflating: training_set/410.mat.pt
#   inflating: __MACOSX/training_set/._410.mat.pt
#   inflating: training_set/241.mat.pt
#   inflating: __MACOSX/training_set/._241.mat.pt
#   inflating: training_set/510.mat.pt
#   inflating: __MACOSX/training_set/._510.mat.pt
#   inflating: training_set/488.mat.pt
#   inflating: __MACOSX/training_set/._488.mat.pt
#   inflating: training_set/588.mat.pt
#   inflating: __MACOSX/training_set/._588.mat.pt
#   inflating: training_set/1677.mat.pt
#   inflating: __MACOSX/training_set/._1677.mat.pt
#   inflating: training_set/1126.mat.pt
#   inflating: __MACOSX/training_set/._1126.mat.pt
#   inflating: training_set/1391.mat.pt
#   inflating: __MACOSX/training_set/._1391.mat.pt
#   inflating: training_set/1777.mat.pt
#   inflating: __MACOSX/training_set/._1777.mat.pt
#   inflating: training_set/1026.mat.pt
#   inflating: __MACOSX/training_set/._1026.mat.pt
#   inflating: training_set/1291.mat.pt
#   inflating: __MACOSX/training_set/._1291.mat.pt
#   inflating: training_set/113.mat.pt
#   inflating: __MACOSX/training_set/._113.mat.pt
#   inflating: training_set/642.mat.pt
#   inflating: __MACOSX/training_set/._642.mat.pt
#   inflating: training_set/52.mat.pt
#   inflating: __MACOSX/training_set/._52.mat.pt
#   inflating: training_set/742.mat.pt
#   inflating: __MACOSX/training_set/._742.mat.pt
#   inflating: training_set/857.mat.pt
#   inflating: __MACOSX/training_set/._857.mat.pt
#   inflating: training_set/957.mat.pt
#   inflating: __MACOSX/training_set/._957.mat.pt
#   inflating: training_set/834.mat.pt
#   inflating: __MACOSX/training_set/._834.mat.pt
#   inflating: training_set/1669.mat.pt
#   inflating: __MACOSX/training_set/._1669.mat.pt
#   inflating: training_set/1138.mat.pt
#   inflating: __MACOSX/training_set/._1138.mat.pt
#   inflating: training_set/934.mat.pt
#   inflating: __MACOSX/training_set/._934.mat.pt
#   inflating: training_set/1769.mat.pt
#   inflating: __MACOSX/training_set/._1769.mat.pt
#   inflating: training_set/1038.mat.pt
#   inflating: __MACOSX/training_set/._1038.mat.pt
#   inflating: training_set/170.mat.pt
#   inflating: __MACOSX/training_set/._170.mat.pt
#   inflating: training_set/621.mat.pt
#   inflating: __MACOSX/training_set/._621.mat.pt
#   inflating: training_set/496.mat.pt
#   inflating: __MACOSX/training_set/._496.mat.pt
#   inflating: training_set/31.mat.pt
#   inflating: __MACOSX/training_set/._31.mat.pt
#   inflating: training_set/721.mat.pt
#   inflating: __MACOSX/training_set/._721.mat.pt
#   inflating: training_set/596.mat.pt
#   inflating: __MACOSX/training_set/._596.mat.pt
#   inflating: training_set/849.mat.pt
#   inflating: __MACOSX/training_set/._849.mat.pt
#   inflating: training_set/1614.mat.pt
#   inflating: __MACOSX/training_set/._1614.mat.pt
#   inflating: training_set/1145.mat.pt
#   inflating: __MACOSX/training_set/._1145.mat.pt
#   inflating: training_set/949.mat.pt
#   inflating: __MACOSX/training_set/._949.mat.pt
#   inflating: training_set/1714.mat.pt
#   inflating: __MACOSX/training_set/._1714.mat.pt
#   inflating: training_set/1045.mat.pt
#   inflating: __MACOSX/training_set/._1045.mat.pt
#   inflating: training_set/1283.mat.pt
#   inflating: __MACOSX/training_set/._1283.mat.pt
#   inflating: training_set/938.mat.pt
#   inflating: __MACOSX/training_set/._938.mat.pt
#   inflating: training_set/1034.mat.pt
#   inflating: __MACOSX/training_set/._1034.mat.pt
#   inflating: training_set/1765.mat.pt
#   inflating: __MACOSX/training_set/._1765.mat.pt
#   inflating: training_set/1383.mat.pt
#   inflating: __MACOSX/training_set/._1383.mat.pt
#   inflating: training_set/838.mat.pt
#   inflating: __MACOSX/training_set/._838.mat.pt
#   inflating: training_set/1134.mat.pt
#   inflating: __MACOSX/training_set/._1134.mat.pt
#   inflating: training_set/1665.mat.pt
#   inflating: __MACOSX/training_set/._1665.mat.pt
#   inflating: training_set/750.mat.pt
#   inflating: __MACOSX/training_set/._750.mat.pt
#   inflating: training_set/40.mat.pt
#   inflating: __MACOSX/training_set/._40.mat.pt
#   inflating: training_set/650.mat.pt
#   inflating: __MACOSX/training_set/._650.mat.pt
#   inflating: training_set/101.mat.pt
#   inflating: __MACOSX/training_set/._101.mat.pt
#   inflating: training_set/945.mat.pt
#   inflating: __MACOSX/training_set/._945.mat.pt
#   inflating: training_set/1049.mat.pt
#   inflating: __MACOSX/training_set/._1049.mat.pt
#   inflating: training_set/1718.mat.pt
#   inflating: __MACOSX/training_set/._1718.mat.pt
#   inflating: training_set/845.mat.pt
#   inflating: __MACOSX/training_set/._845.mat.pt
#   inflating: training_set/1149.mat.pt
#   inflating: __MACOSX/training_set/._1149.mat.pt
#   inflating: training_set/1618.mat.pt
#   inflating: __MACOSX/training_set/._1618.mat.pt
#   inflating: training_set/926.mat.pt
#   inflating: __MACOSX/training_set/._926.mat.pt
#   inflating: training_set/826.mat.pt
#   inflating: __MACOSX/training_set/._826.mat.pt
#   inflating: training_set/584.mat.pt
#   inflating: __MACOSX/training_set/._584.mat.pt
#   inflating: training_set/733.mat.pt
#   inflating: __MACOSX/training_set/._733.mat.pt
#   inflating: training_set/23.mat.pt
#   inflating: __MACOSX/training_set/._23.mat.pt
#   inflating: training_set/484.mat.pt
#   inflating: __MACOSX/training_set/._484.mat.pt
#   inflating: training_set/633.mat.pt
#   inflating: __MACOSX/training_set/._633.mat.pt
#   inflating: training_set/162.mat.pt
#   inflating: __MACOSX/training_set/._162.mat.pt
#   inflating: training_set/1057.mat.pt
#   inflating: __MACOSX/training_set/._1057.mat.pt
#   inflating: training_set/1706.mat.pt
#   inflating: __MACOSX/training_set/._1706.mat.pt
#   inflating: training_set/1157.mat.pt
#   inflating: __MACOSX/training_set/._1157.mat.pt
#   inflating: training_set/1606.mat.pt
#   inflating: __MACOSX/training_set/._1606.mat.pt
#   inflating: training_set/1753.mat.pt
#   inflating: __MACOSX/training_set/._1753.mat.pt
#   inflating: training_set/1002.mat.pt
#   inflating: __MACOSX/training_set/._1002.mat.pt
#   inflating: training_set/1653.mat.pt
#   inflating: __MACOSX/training_set/._1653.mat.pt
#   inflating: training_set/1102.mat.pt
#   inflating: __MACOSX/training_set/._1102.mat.pt
#   inflating: training_set/1599.mat.pt
#   inflating: __MACOSX/training_set/._1599.mat.pt
#   inflating: training_set/973.mat.pt
#   inflating: __MACOSX/training_set/._973.mat.pt
#   inflating: training_set/1499.mat.pt
#   inflating: __MACOSX/training_set/._1499.mat.pt
#   inflating: training_set/873.mat.pt
#   inflating: __MACOSX/training_set/._873.mat.pt
#   inflating: training_set/280.mat.pt
#   inflating: __MACOSX/training_set/._280.mat.pt
#   inflating: training_set/76.mat.pt
#   inflating: __MACOSX/training_set/._76.mat.pt
#   inflating: training_set/766.mat.pt
#   inflating: __MACOSX/training_set/._766.mat.pt
#   inflating: training_set/380.mat.pt
#   inflating: __MACOSX/training_set/._380.mat.pt
#   inflating: training_set/137.mat.pt
#   inflating: __MACOSX/training_set/._137.mat.pt
#   inflating: training_set/666.mat.pt
#   inflating: __MACOSX/training_set/._666.mat.pt
#   inflating: training_set/15.mat.pt
#   inflating: __MACOSX/training_set/._15.mat.pt
#   inflating: training_set/705.mat.pt
#   inflating: __MACOSX/training_set/._705.mat.pt
#   inflating: training_set/154.mat.pt
#   inflating: __MACOSX/training_set/._154.mat.pt
# ...
#   inflating: __MACOSX/validation_set/._323.mat.pt
#   inflating: validation_set/472.mat.pt
#   inflating: __MACOSX/validation_set/._472.mat.pt
#   inflating: validation_set/9.mat.pt
#   inflating: __MACOSX/validation_set/._9.mat.pt
#   inflating: validation_set/80.mat.pt
#   inflating: __MACOSX/validation_set/._80.mat.pt
#   inflating: validation_set/276.mat.pt
#   inflating: __MACOSX/validation_set/._276.mat.pt
#   inflating: validation_set/427.mat.pt
#   inflating: __MACOSX/validation_set/._427.mat.pt
#   inflating: validation_set/376.mat.pt
#   inflating: __MACOSX/validation_set/._376.mat.pt
#   inflating: validation_set/268.mat.pt
#   inflating: __MACOSX/validation_set/._268.mat.pt
#   inflating: validation_set/439.mat.pt
#   inflating: __MACOSX/validation_set/._439.mat.pt
#   inflating: validation_set/368.mat.pt
#   inflating: __MACOSX/validation_set/._368.mat.pt
#   inflating: validation_set/215.mat.pt
#   inflating: __MACOSX/validation_set/._215.mat.pt
#   inflating: validation_set/444.mat.pt
#   inflating: __MACOSX/validation_set/._444.mat.pt
#   inflating: validation_set/315.mat.pt
#   inflating: __MACOSX/validation_set/._315.mat.pt
#   inflating: validation_set/364.mat.pt
#   inflating: __MACOSX/validation_set/._364.mat.pt
#   inflating: validation_set/435.mat.pt
#   inflating: __MACOSX/validation_set/._435.mat.pt
#   inflating: validation_set/264.mat.pt
#   inflating: __MACOSX/validation_set/._264.mat.pt
#   inflating: validation_set/92.mat.pt
#   inflating: __MACOSX/validation_set/._92.mat.pt
#   inflating: validation_set/319.mat.pt
#   inflating: __MACOSX/validation_set/._319.mat.pt
#   inflating: validation_set/448.mat.pt
#   inflating: __MACOSX/validation_set/._448.mat.pt
#   inflating: validation_set/219.mat.pt
#   inflating: __MACOSX/validation_set/._219.mat.pt
#   inflating: validation_set/307.mat.pt
#   inflating: __MACOSX/validation_set/._307.mat.pt
#   inflating: validation_set/456.mat.pt
#   inflating: __MACOSX/validation_set/._456.mat.pt
#   inflating: validation_set/207.mat.pt
#   inflating: __MACOSX/validation_set/._207.mat.pt
#   inflating: validation_set/481.mat.pt
#   inflating: __MACOSX/validation_set/._481.mat.pt
#   inflating: validation_set/167.mat.pt
#   inflating: __MACOSX/validation_set/._167.mat.pt
#   inflating: validation_set/26.mat.pt
#   inflating: __MACOSX/validation_set/._26.mat.pt
#   inflating: validation_set/179.mat.pt
#   inflating: __MACOSX/validation_set/._179.mat.pt
#   inflating: validation_set/38.mat.pt
#   inflating: __MACOSX/validation_set/._38.mat.pt
#   inflating: validation_set/104.mat.pt
#   inflating: __MACOSX/validation_set/._104.mat.pt
#   inflating: validation_set/45.mat.pt
#   inflating: __MACOSX/validation_set/._45.mat.pt
#   inflating: validation_set/34.mat.pt
#   inflating: __MACOSX/validation_set/._34.mat.pt
#   inflating: validation_set/175.mat.pt
#   inflating: __MACOSX/validation_set/._175.mat.pt
#   inflating: validation_set/493.mat.pt
#   inflating: __MACOSX/validation_set/._493.mat.pt
#   inflating: validation_set/49.mat.pt
#   inflating: __MACOSX/validation_set/._49.mat.pt
#   inflating: validation_set/108.mat.pt
#   inflating: __MACOSX/validation_set/._108.mat.pt
#   inflating: validation_set/57.mat.pt
#   inflating: __MACOSX/validation_set/._57.mat.pt
#   inflating: validation_set/116.mat.pt
#   inflating: __MACOSX/validation_set/._116.mat.pt
#   inflating: validation_set/143.mat.pt
#   inflating: __MACOSX/validation_set/._143.mat.pt
#   inflating: validation_set/289.mat.pt
#   inflating: __MACOSX/validation_set/._289.mat.pt
#   inflating: validation_set/389.mat.pt
#   inflating: __MACOSX/validation_set/._389.mat.pt
#   inflating: validation_set/61.mat.pt
#   inflating: __MACOSX/validation_set/._61.mat.pt
#   inflating: validation_set/297.mat.pt
#   inflating: __MACOSX/validation_set/._297.mat.pt
#   inflating: validation_set/120.mat.pt
#   inflating: __MACOSX/validation_set/._120.mat.pt
#   inflating: validation_set/397.mat.pt
#   inflating: __MACOSX/validation_set/._397.mat.pt
#   inflating: validation_set/151.mat.pt
#   inflating: __MACOSX/validation_set/._151.mat.pt
#   inflating: validation_set/10.mat.pt
#   inflating: __MACOSX/validation_set/._10.mat.pt
#   inflating: validation_set/385.mat.pt
#   inflating: __MACOSX/validation_set/._385.mat.pt
#   inflating: validation_set/132.mat.pt
#   inflating: __MACOSX/validation_set/._132.mat.pt
#   inflating: validation_set/285.mat.pt
#   inflating: __MACOSX/validation_set/._285.mat.pt
#   inflating: validation_set/73.mat.pt
#   inflating: __MACOSX/validation_set/._73.mat.pt
#   inflating: validation_set/431.mat.pt
#   inflating: __MACOSX/validation_set/._431.mat.pt
#   inflating: validation_set/360.mat.pt
#   inflating: __MACOSX/validation_set/._360.mat.pt
#   inflating: validation_set/260.mat.pt
#   inflating: __MACOSX/validation_set/._260.mat.pt
#   inflating: validation_set/96.mat.pt
#   inflating: __MACOSX/validation_set/._96.mat.pt
#   inflating: validation_set/452.mat.pt
#   inflating: __MACOSX/validation_set/._452.mat.pt
#   inflating: validation_set/303.mat.pt
#   inflating: __MACOSX/validation_set/._303.mat.pt
#   inflating: validation_set/203.mat.pt
#   inflating: __MACOSX/validation_set/._203.mat.pt
#   inflating: validation_set/88.mat.pt
#   inflating: __MACOSX/validation_set/._88.mat.pt
#   inflating: validation_set/84.mat.pt
#   inflating: __MACOSX/validation_set/._84.mat.pt
#   inflating: validation_set/272.mat.pt
#   inflating: __MACOSX/validation_set/._272.mat.pt
#   inflating: validation_set/372.mat.pt
#   inflating: __MACOSX/validation_set/._372.mat.pt
#   inflating: validation_set/423.mat.pt
#   inflating: __MACOSX/validation_set/._423.mat.pt
#   inflating: validation_set/211.mat.pt
#   inflating: __MACOSX/validation_set/._211.mat.pt
#   inflating: validation_set/311.mat.pt
#   inflating: __MACOSX/validation_set/._311.mat.pt
#   inflating: validation_set/440.mat.pt
#   inflating: __MACOSX/validation_set/._440.mat.pt
#   inflating: validation_set/239.mat.pt
#   inflating: __MACOSX/validation_set/._239.mat.pt
#   inflating: validation_set/468.mat.pt
#   inflating: __MACOSX/validation_set/._468.mat.pt
#   inflating: validation_set/339.mat.pt
#   inflating: __MACOSX/validation_set/._339.mat.pt
#   inflating: validation_set/244.mat.pt
#   inflating: __MACOSX/validation_set/._244.mat.pt
#   inflating: validation_set/415.mat.pt
#   inflating: __MACOSX/validation_set/._415.mat.pt
#   inflating: validation_set/344.mat.pt
#   inflating: __MACOSX/validation_set/._344.mat.pt
#   inflating: validation_set/227.mat.pt
#   inflating: __MACOSX/validation_set/._227.mat.pt
#   inflating: validation_set/190.mat.pt
#   inflating: __MACOSX/validation_set/._190.mat.pt
#   inflating: validation_set/476.mat.pt
#   inflating: __MACOSX/validation_set/._476.mat.pt
#   inflating: validation_set/327.mat.pt
#   inflating: __MACOSX/validation_set/._327.mat.pt
#   inflating: validation_set/1.mat.pt
#   inflating: __MACOSX/validation_set/._1.mat.pt
#   inflating: validation_set/356.mat.pt
#   inflating: __MACOSX/validation_set/._356.mat.pt
#   inflating: validation_set/407.mat.pt
#   inflating: __MACOSX/validation_set/._407.mat.pt
#   inflating: validation_set/256.mat.pt
#   inflating: __MACOSX/validation_set/._256.mat.pt
#   inflating: validation_set/335.mat.pt
#   inflating: __MACOSX/validation_set/._335.mat.pt
#   inflating: validation_set/464.mat.pt
#   inflating: __MACOSX/validation_set/._464.mat.pt
#   inflating: validation_set/182.mat.pt
#   inflating: __MACOSX/validation_set/._182.mat.pt
#   inflating: validation_set/235.mat.pt
#   inflating: __MACOSX/validation_set/._235.mat.pt
#   inflating: validation_set/348.mat.pt
#   inflating: __MACOSX/validation_set/._348.mat.pt
#   inflating: validation_set/419.mat.pt
#   inflating: __MACOSX/validation_set/._419.mat.pt
#   inflating: validation_set/248.mat.pt
#   inflating: __MACOSX/validation_set/._248.mat.pt
#   inflating: validation_set/128.mat.pt
#   inflating: __MACOSX/validation_set/._128.mat.pt
#   inflating: validation_set/69.mat.pt
#   inflating: __MACOSX/validation_set/._69.mat.pt
#   inflating: validation_set/155.mat.pt
#   inflating: __MACOSX/validation_set/._155.mat.pt
#   inflating: validation_set/14.mat.pt
#   inflating: __MACOSX/validation_set/._14.mat.pt
#   inflating: validation_set/381.mat.pt
#   inflating: __MACOSX/validation_set/._381.mat.pt
#   inflating: validation_set/136.mat.pt
#   inflating: __MACOSX/validation_set/._136.mat.pt
#   inflating: validation_set/281.mat.pt
#   inflating: __MACOSX/validation_set/._281.mat.pt
#   inflating: validation_set/77.mat.pt
#   inflating: __MACOSX/validation_set/._77.mat.pt
#   inflating: validation_set/147.mat.pt
#   inflating: __MACOSX/validation_set/._147.mat.pt
#   inflating: validation_set/65.mat.pt
#   inflating: __MACOSX/validation_set/._65.mat.pt
#   inflating: validation_set/293.mat.pt
#   inflating: __MACOSX/validation_set/._293.mat.pt
#   inflating: validation_set/124.mat.pt
#   inflating: __MACOSX/validation_set/._124.mat.pt
#   inflating: validation_set/393.mat.pt
#   inflating: __MACOSX/validation_set/._393.mat.pt
#   inflating: validation_set/18.mat.pt
#   inflating: __MACOSX/validation_set/._18.mat.pt
#   inflating: validation_set/159.mat.pt
#   inflating: __MACOSX/validation_set/._159.mat.pt
#   inflating: validation_set/30.mat.pt
#   inflating: __MACOSX/validation_set/._30.mat.pt
#   inflating: validation_set/171.mat.pt
#   inflating: __MACOSX/validation_set/._171.mat.pt
#   inflating: validation_set/497.mat.pt
#   inflating: __MACOSX/validation_set/._497.mat.pt
#   inflating: validation_set/53.mat.pt
#   inflating: __MACOSX/validation_set/._53.mat.pt
#   inflating: validation_set/112.mat.pt
#   inflating: __MACOSX/validation_set/._112.mat.pt
#   inflating: validation_set/489.mat.pt
#   inflating: __MACOSX/validation_set/._489.mat.pt
#   inflating: validation_set/485.mat.pt
#   inflating: __MACOSX/validation_set/._485.mat.pt
#   inflating: validation_set/163.mat.pt
#   inflating: __MACOSX/validation_set/._163.mat.pt
#   inflating: validation_set/22.mat.pt
#   inflating: __MACOSX/validation_set/._22.mat.pt
#   inflating: validation_set/100.mat.pt
#   inflating: __MACOSX/validation_set/._100.mat.pt
#   inflating: validation_set/41.mat.pt
#   inflating: __MACOSX/validation_set/._41.mat.pt
#   inflating: validation_set/67.mat.pt
#   inflating: __MACOSX/validation_set/._67.mat.pt
#   inflating: validation_set/291.mat.pt
#   inflating: __MACOSX/validation_set/._291.mat.pt
#   inflating: validation_set/126.mat.pt
#   inflating: __MACOSX/validation_set/._126.mat.pt
#   inflating: validation_set/391.mat.pt
#   inflating: __MACOSX/validation_set/._391.mat.pt
#   inflating: validation_set/79.mat.pt
#   inflating: __MACOSX/validation_set/._79.mat.pt
#   inflating: validation_set/138.mat.pt
#   inflating: __MACOSX/validation_set/._138.mat.pt
#   inflating: validation_set/145.mat.pt
#   inflating: __MACOSX/validation_set/._145.mat.pt
#   inflating: validation_set/383.mat.pt
#   inflating: __MACOSX/validation_set/._383.mat.pt
#   inflating: validation_set/134.mat.pt
#   inflating: __MACOSX/validation_set/._134.mat.pt
#   inflating: validation_set/283.mat.pt
#   inflating: __MACOSX/validation_set/._283.mat.pt
#   inflating: validation_set/75.mat.pt
#   inflating: __MACOSX/validation_set/._75.mat.pt
#   inflating: validation_set/149.mat.pt
#   inflating: __MACOSX/validation_set/._149.mat.pt
#   inflating: validation_set/157.mat.pt
#   inflating: __MACOSX/validation_set/._157.mat.pt
#   inflating: validation_set/16.mat.pt
#   inflating: __MACOSX/validation_set/._16.mat.pt
#   inflating: validation_set/102.mat.pt
#   inflating: __MACOSX/validation_set/._102.mat.pt
#   inflating: validation_set/43.mat.pt
#   inflating: __MACOSX/validation_set/._43.mat.pt
#   inflating: validation_set/499.mat.pt
#   inflating: __MACOSX/validation_set/._499.mat.pt
#   inflating: validation_set/487.mat.pt
#   inflating: __MACOSX/validation_set/._487.mat.pt
#   inflating: validation_set/161.mat.pt
#   inflating: __MACOSX/validation_set/._161.mat.pt
#   inflating: validation_set/20.mat.pt
#   inflating: __MACOSX/validation_set/._20.mat.pt
#   inflating: validation_set/51.mat.pt
#   inflating: __MACOSX/validation_set/._51.mat.pt
#   inflating: validation_set/110.mat.pt
#   inflating: __MACOSX/validation_set/._110.mat.pt
#   inflating: validation_set/32.mat.pt
#   inflating: __MACOSX/validation_set/._32.mat.pt
#   inflating: validation_set/173.mat.pt
#   inflating: __MACOSX/validation_set/._173.mat.pt
#   inflating: validation_set/495.mat.pt
#   inflating: __MACOSX/validation_set/._495.mat.pt
#   inflating: validation_set/213.mat.pt
#   inflating: __MACOSX/validation_set/._213.mat.pt
#   inflating: validation_set/313.mat.pt
#   inflating: __MACOSX/validation_set/._313.mat.pt
#   inflating: validation_set/442.mat.pt
#   inflating: __MACOSX/validation_set/._442.mat.pt
#   inflating: validation_set/98.mat.pt
#   inflating: __MACOSX/validation_set/._98.mat.pt
#   inflating: validation_set/86.mat.pt
#   inflating: __MACOSX/validation_set/._86.mat.pt
#   inflating: validation_set/270.mat.pt
#   inflating: __MACOSX/validation_set/._270.mat.pt
#   inflating: validation_set/370.mat.pt
#   inflating: __MACOSX/validation_set/._370.mat.pt
#   inflating: validation_set/421.mat.pt
#   inflating: __MACOSX/validation_set/._421.mat.pt
#   inflating: validation_set/450.mat.pt
#   inflating: __MACOSX/validation_set/._450.mat.pt
#   inflating: validation_set/301.mat.pt
#   inflating: __MACOSX/validation_set/._301.mat.pt
#   inflating: validation_set/201.mat.pt
#   inflating: __MACOSX/validation_set/._201.mat.pt
#   inflating: validation_set/433.mat.pt
#   inflating: __MACOSX/validation_set/._433.mat.pt
#   inflating: validation_set/362.mat.pt
#   inflating: __MACOSX/validation_set/._362.mat.pt
#   inflating: validation_set/262.mat.pt
#   inflating: __MACOSX/validation_set/._262.mat.pt
#   inflating: validation_set/94.mat.pt
#   inflating: __MACOSX/validation_set/._94.mat.pt
#   inflating: validation_set/337.mat.pt
#   inflating: __MACOSX/validation_set/._337.mat.pt
#   inflating: validation_set/466.mat.pt
#   inflating: __MACOSX/validation_set/._466.mat.pt
#   inflating: validation_set/180.mat.pt
#   inflating: __MACOSX/validation_set/._180.mat.pt
#   inflating: validation_set/237.mat.pt
#   inflating: __MACOSX/validation_set/._237.mat.pt
#   inflating: validation_set/329.mat.pt
#   inflating: __MACOSX/validation_set/._329.mat.pt
#   inflating: validation_set/478.mat.pt
#   inflating: __MACOSX/validation_set/._478.mat.pt
#   inflating: validation_set/229.mat.pt
#   inflating: __MACOSX/validation_set/._229.mat.pt
#   inflating: validation_set/3.mat.pt
#   inflating: __MACOSX/validation_set/._3.mat.pt
#   inflating: validation_set/354.mat.pt
#   inflating: __MACOSX/validation_set/._354.mat.pt
#   inflating: validation_set/405.mat.pt
#   inflating: __MACOSX/validation_set/._405.mat.pt
#   inflating: validation_set/254.mat.pt
#   inflating: __MACOSX/validation_set/._254.mat.pt
#   inflating: validation_set/225.mat.pt
#   inflating: __MACOSX/validation_set/._225.mat.pt
#   inflating: validation_set/192.mat.pt
#   inflating: __MACOSX/validation_set/._192.mat.pt
#   inflating: validation_set/474.mat.pt
#   inflating: __MACOSX/validation_set/._474.mat.pt
#   inflating: validation_set/325.mat.pt
#   inflating: __MACOSX/validation_set/._325.mat.pt
#   inflating: validation_set/258.mat.pt
#   inflating: __MACOSX/validation_set/._258.mat.pt
#   inflating: validation_set/409.mat.pt
#   inflating: __MACOSX/validation_set/._409.mat.pt
#   inflating: validation_set/358.mat.pt
#   inflating: __MACOSX/validation_set/._358.mat.pt
#   inflating: validation_set/246.mat.pt
#   inflating: __MACOSX/validation_set/._246.mat.pt
#   inflating: validation_set/417.mat.pt
#   inflating: __MACOSX/validation_set/._417.mat.pt
#   inflating: validation_set/346.mat.pt
#   inflating: __MACOSX/validation_set/._346.mat.pt

# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import random
from sklearn.model_selection import train_test_split
import torch.nn.functional as F
data_path = '/content/training_set'
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, file_paths):
        self.file_paths = file_paths
        self.static_idx = torch.tensor([0,2,4])
        self.dynamic_idx = torch.tensor([1,3,5])


    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        data = torch.load(self.file_paths[idx])

        imgs_in  = data[:6].float()                 # [6, H, W] in original interleaved order
        static3  = imgs_in.index_select(0, self.static_idx)   # [3, H, W]
        dynamic3 = imgs_in.index_select(0, self.dynamic_idx)  # [3, H, W]
        images   = torch.cat([static3, dynamic3], dim=0)

        labels = data[6]

        images = images.float()
        labels = labels.long()

        return images, labels

class TrainDataset(CustomDataset):
    def __getitem__(self, idx):
        images, labels = super().__getitem__(idx)

        if random.random() < 0.5:
            images[0] = images[0].flip(-1)
            images[1] = images[1].flip(-1)
            labels = labels.flip(-1)

        return images, labels

file_paths = [f'{data_path}/{file}' for file in os.listdir(data_path) if file.endswith('.mat.pt')]

train_dataset = TrainDataset(file_paths=file_paths)

train_loader = torch.utils.data.DataLoader(
    dataset = train_dataset,
    shuffle = True,
    batch_size = 32,
    num_workers = 2,
    drop_last = True,
    pin_memory = True
)

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.s = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size= 3, padding='same'),
            nn.BatchNorm2d(out_channels),
            nn.GELU(),
            nn.Dropout2d(0.3),
            nn.Conv2d(out_channels, out_channels, kernel_size= 3, padding='same'),
            nn.BatchNorm2d(out_channels),
            nn.GELU(),
        )
    def forward(self, x):
        return self.s(x)

# %%
class ResBlock2d(nn.Module):
  def __init__(self, in_channels, out_channels,res_scale=1.0):
    super().__init__()
    self.proj = nn.Conv2d(in_channels, out_channels, 1, bias=False)
    self.res_scale = res_scale

    self.block = DoubleConv(in_channels, out_channels)

  def forward(self, x):
    y = self.block(x)
    s = self.proj(x)
    return F.relu(s + self.res_scale * y, inplace=True)

# %%
class Encode(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = ResBlock2d(in_channels, out_channels)
        self.pool = nn.MaxPool2d(2)
        self.dropout = nn.Dropout2d(0.3)
    def forward(self, x):
        x = self.conv(x)
        p = self.pool(x)
        p = self.dropout(p)
        return x, p

# %%
class AttentionGate(nn.Module):
    def __init__(self, F_g, F_l, F_int):
        super().__init__()
        self.W_g = nn.Sequential(
            nn.Conv2d(F_g, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )
        self.W_x = nn.Sequential(
            nn.Conv2d(F_l, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )
        self.psi = nn.Sequential(
            nn.Conv2d(F_int, 1, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )
        self.relu = nn.ReLU(inplace=True)

    def forward(self, g, x):  # g = decoder feature, x = encoder skip feature
        g1 = self.W_g(g)
        x1 = self.W_x(x)
        psi = self.relu(g1 + x1)
        psi = self.psi(psi)
        return x * psi  # element-wise gating

# %%
class Decode(nn.Module):
    def __init__(self, in_channels, skip, out_channels, pad):
        super().__init__()
        # F_g must be out_channels, not in_channels
        self.attn = AttentionGate(F_g=out_channels, F_l=skip, F_int=skip // 2)

        self.unpool = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2, output_padding=pad)
        self.dropout = nn.Dropout2d(0.3)
        self.conv = ResBlock2d(out_channels + skip, out_channels)

    def forward(self, x, skip):
        x = self.unpool(x)
        skip = self.attn(x, skip)
        x = torch.cat([x, skip], dim=1)
        x = self.dropout(x)
        x = self.conv(x)
        return x

# %%
class DuoUNet(nn.Module):
    def __init__(self, in_channels=6, num_filters=32, num_classes=2):
        super().__init__()
        # Two encoders: static (0–2), dynamic (3–5)
        self.enc_s1 = Encode(3, num_filters)
        self.enc_s2 = Encode(num_filters, num_filters*2)
        self.enc_s3 = Encode(num_filters*2, num_filters*4)
        self.enc_s4 = Encode(num_filters*4, num_filters*8)

        self.enc_d1 = Encode(3, num_filters)
        self.enc_d2 = Encode(num_filters, num_filters*2)
        self.enc_d3 = Encode(num_filters*2, num_filters*4)
        self.enc_d4 = Encode(num_filters*4, num_filters*8)

        # Fusion (1x1 convs to mix static + dynamic features)
        def fuse(in_ch): return nn.Conv2d(in_ch * 2, in_ch, kernel_size=1, bias=False)
        self.fuse1 = fuse(num_filters)
        self.fuse2 = fuse(num_filters*2)
        self.fuse3 = fuse(num_filters*4)
        self.fuse4 = fuse(num_filters*8)

        # Shared bridge
        self.bridge = DoubleConv(num_filters*8, num_filters*16)

        # Shared decoder (attention + residual)
        self.up1 = Decode(num_filters*16, num_filters*8, num_filters*8, (0, 0))
        self.up2 = Decode(num_filters*8, num_filters*4, num_filters*4, (0, 1))
        self.up3 = Decode(num_filters*4, num_filters*2, num_filters*2, (1, 0))
        self.up4 = Decode(num_filters*2, num_filters, num_filters, (0, 1))

        self.out_conv = nn.Conv2d(num_filters, num_classes, kernel_size=1)

    def forward(self, x):
        # Split input
        xs, xd = [x[0], x[2], x[4]], [x[1], x[3], [x[5]]]

        # Encoder static
        x1s, xs = self.enc_s1(xs)
        x2s, xs = self.enc_s2(xs)
        x3s, xs = self.enc_s3(xs)
        x4s, xs = self.enc_s4(xs)

        # Encoder dynamic
        x1d, xd = self.enc_d1(xd)
        x2d, xd = self.enc_d2(xd)
        x3d, xd = self.enc_d3(xd)
        x4d, xd = self.enc_d4(xd)

        # Fuse static + dynamic features at each level
        x1 = self.fuse1(torch.cat([x1s, x1d], dim=1))
        x2 = self.fuse2(torch.cat([x2s, x2d], dim=1))
        x3 = self.fuse3(torch.cat([x3s, x3d], dim=1))
        x4 = self.fuse4(torch.cat([x4s, x4d], dim=1))

        # Bridge
        x = self.bridge(x4)

        # Decode
        x = self.up1(x, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)

        return self.out_conv(x)

# %%
class GroupedStem(nn.Module):
    def __init__(self, in_channels=6, out_channels=32, groups=3):
        super().__init__()
        mid = out_channels * groups
        self.net = nn.Sequential(
            nn.Conv2d(in_channels, mid, 3, padding=1, groups=groups, bias=False),
            nn.BatchNorm2d(mid),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid, out_channels, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )
    def forward(self, x):
     return self.net(x)

# %%
class TriNet(nn.Module):
    def __init__(self, in_channels=6, num_filters=32, num_classes=2):
        super().__init__()
        self.stem = GroupedStem(in_channels, num_filters, groups=3)
        self.down1 = Encode(num_filters, num_filters * 2)
        self.down2 = Encode(num_filters * 2, num_filters * 4)
        self.down3 = Encode(num_filters * 4, num_filters * 8)
        self.bridge = DoubleConv(num_filters * 8, num_filters * 16)
        self.up1 = Decode(num_filters * 16, num_filters * 8, num_filters * 8, (0, 0))
        self.up2 = Decode(num_filters * 8, num_filters * 4, num_filters * 4, (0, 1))
        self.up3 = Decode(num_filters * 4, num_filters * 2, num_filters * 2, (1, 0))
        self.up4 = Decode(num_filters * 2, num_filters, num_filters, (0, 1))
        self.out_conv = nn.Conv2d(num_filters, num_classes, 1)

    def forward(self, x):
        x0 = self.stem(x)
        x1, x = self.down1(x0)
        x2, x = self.down2(x)
        x3, x = self.down3(x)
        x = self.bridge(x)
        x = self.up1(x, x3)
        x = self.up2(x, x2)
        x = self.up3(x, x1)
        x = self.up4(x, x0)
        return self.out_conv(x)

# %%
class MegaEnsemble(nn.Module):
    def __init__(self, num_filters=32, num_classes=2):
        super().__init__()
        self.tri = TriNet(num_filters=num_filters, num_classes=num_classes)
        self.double = DuoUNet(num_filters=num_filters, num_classes=num_classes)

    def forward(self, x):
        out_tri = self.tri(x)        # logits from geometry-grouped
        out_double = self.double(x)  # logits from modality-grouped
        return (out_tri + out_double) / 2  # average logits

# %%
def train(model):


    model.train()
    model.to(device)
    class_weights = torch.tensor([1., 1500.,])
    loss_fn = nn.CrossEntropyLoss(
        weight = class_weights, reduction='mean'
    )

    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    warmup = 1
    epochs = 9

    main_sch = torch.optim.lr_scheduler.LinearLR(
        optimizer, start_factor=1.0, end_factor=0.0, total_iters = epochs * len(train_loader)
    )
    warmup_sch = torch.optim.lr_scheduler.LinearLR(
        optimizer, start_factor=0.01, end_factor=1.0, total_iters = warmup * len(train_loader)
    )
    scheduler = torch.optim.lr_scheduler.SequentialLR(
        optimizer, schedulers = [warmup_sch, main_sch], milestones = [warmup * len(train_loader)]
    )

    scaler = torch.amp.GradScaler(device)

    for epoch in range(warmup+epochs):
        print(f'Epoch {epoch}:')

        model.train()

        running_loss = 0.0
        correct = 0.0

        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            with torch.amp.autocast(device):
                outputs = model(x)
                loss = loss_fn(outputs, y)

                optimizer.zero_grad()
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

                scheduler.step()
                running_loss += loss.item()

                _, predicted = torch.max(outputs, 1)
                weights = class_weights[y]  # Get weight for each sample's true class
                correct = (predicted == y).float()
                weighted_correct = correct * weights
                weighted_accuracy = weighted_correct.sum() / weights.sum()


        running_loss /= len(train_loader)
        train_acc = 100 * weighted_accuracy / len(train_loader)
        print(f'Train Loss : {running_loss}')
        print(f'Train Accuracy : {train_acc:.2f}')

    return model, running_loss

# %%
class MyModel(nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()
        self.models = nn.ModuleList(MegaEnsemble() for _ in range(5))

    def forward(self, x):
        return sum(model(x) for model in self.models) / len(self.models)

# %%
model = MyModel()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3932546801.py in <cell line: 0>()
# ----> 1 model = MyModel()
#
# /tmp/ipython-input-3999747320.py in __init__(self)
#       2     def __init__(self):
#       3         super(MyModel, self).__init__()
# ----> 4         self.models = nn.ModuleList(MegaEnsemble() for _ in range(5))
#       5
#       6     def forward(self, x):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/container.py in __init__(self, modules)
#     308         super().__init__()
#     309         if modules is not None:
# --> 310             self += modules
#     311
#     312     def _get_abs_string_index(self, idx):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/container.py in __iadd__(self, modules)
#     357
#     358     def __iadd__(self, modules: Iterable[Module]) -> Self:
# --> 359         return self.extend(modules)
#     360
#     361     def __add__(self, other: Iterable[Module]) -> "ModuleList":
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/container.py in extend(self, modules)
#     440             )
#     441         offset = len(self)
# --> 442         for i, module in enumerate(modules):
#     443             self.add_module(str(offset + i), module)
#     444         return self
#
# /tmp/ipython-input-3999747320.py in <genexpr>(.0)
#       2     def __init__(self):
#       3         super(MyModel, self).__init__()
# ----> 4         self.models = nn.ModuleList(MegaEnsemble() for _ in range(5))
#       5
#       6     def forward(self, x):
#
# /tmp/ipython-input-4119067949.py in __init__(self, num_filters, num_classes)
#       3         super().__init__()
#       4         self.tri = TriNet(num_filters=num_filters, num_classes=num_classes)
# ----> 5         self.double = DuoUNet(num_filters=num_filters, num_classes=num_classes)
#       6
#       7     def forward(self, x):
#
# NameError: name 'DuoUNet' is not defined

# %%
train(model)
# Out:
# Epoch 0:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2658576871.py in <cell line: 0>()
# ----> 1 train(model)
#
# /tmp/ipython-input-819630517.py in train(model)
#      38
#      39             with torch.amp.autocast(device):
# ---> 40                 outputs = model(x)
#      41                 loss = loss_fn(outputs, y)
#      42
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /tmp/ipython-input-2313039661.py in forward(self, x)
#       5
#       6     def forward(self, x):
# ----> 7         return sum(model(x) for model in self.models) / len(self.models)
#
# /tmp/ipython-input-2313039661.py in <genexpr>(.0)
#       5
#       6     def forward(self, x):
# ----> 7         return sum(model(x) for model in self.models) / len(self.models)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /tmp/ipython-input-3398567565.py in forward(self, x)
#      18
#      19     def forward(self, x):
# ---> 20         x1, x = self.down1(x)
#      21         x2, x = self.down2(x)
#      22         x3, x = self.down3(x)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /tmp/ipython-input-853577212.py in forward(self, x)
#       6         self.dropout = nn.Dropout2d(0.3)
#       7     def forward(self, x):
# ----> 8         x = self.conv(x)
#       9         p = self.pool(x)
#      10         p = self.dropout(p)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /tmp/ipython-input-286008397.py in forward(self, x)
#       8
#       9   def forward(self, x):
# ---> 10     y = self.block(x)
#      11     s = self.proj(x)
#      12     return F.relu(s + self.res_scale * y, inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /tmp/ipython-input-1335435514.py in forward(self, x)
#      12         )
#      13     def forward(self, x):
# ---> 14         return self.s(x)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     248     def forward(self, input):
#     249         for module in self:
# --> 250             input = module(input)
#     251         return input
#     252
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     552
#     553     def forward(self, input: Tensor) -> Tensor:
# --> 554         return self._conv_forward(input, self.weight, self.bias)
#     555
#     556
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     547                 self.groups,
#     548             )
# --> 549         return F.conv2d(
#     550             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551         )
#
# KeyboardInterrupt:

# %%
# Please write your model code (including the necessary imported modules, such as torch and torch.nn) below to generate a model structure file that can be easily loaded by the grading platform
model_code = """
import torch
import torch.nn as nn

class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.s = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size= 3, padding='same'),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Dropout2d(0.3),
            nn.Conv2d(out_channels, out_channels, kernel_size= 3, padding='same'),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )
    def forward(self, x):
        return self.s(x)

class ResBlock2d(nn.Module):
  def __init__(self, in_channels, out_channels,res_scale=1.0):
    super().__init__()
    self.proj = nn.Conv2d(in_channels, out_channels, 1, bias=False)
    self.res_scale = res_scale

    self.block = DoubleConv(in_channels, out_channels)

  def forward(self, x):
    y = self.block(x)
    s = self.proj(x)
    return F.relu(s + self.res_scale * y, inplace=True)

class Encode(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = ResBlock2d(in_channels, out_channels)
        self.pool = nn.MaxPool2d(2)
        self.dropout = nn.Dropout2d(0.3)
    def forward(self, x):
        x = self.conv(x)
        p = self.pool(x)
        p = self.dropout(p)
        return x, p

class AttentionGate(nn.Module):
    def __init__(self, F_g, F_l, F_int):
        super().__init__()
        self.W_g = nn.Sequential(
            nn.Conv2d(F_g, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )
        self.W_x = nn.Sequential(
            nn.Conv2d(F_l, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )
        self.psi = nn.Sequential(
            nn.Conv2d(F_int, 1, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )
        self.relu = nn.ReLU(inplace=True)

    def forward(self, g, x):  # g = decoder feature, x = encoder skip feature
        g1 = self.W_g(g)
        x1 = self.W_x(x)
        psi = self.relu(g1 + x1)
        psi = self.psi(psi)
        return x * psi  # element-wise gating


class Decode(nn.Module):
    def __init__(self, in_channels, skip, out_channels, pad):
        super().__init__()
        # F_g must be out_channels, not in_channels
        self.attn = AttentionGate(F_g=out_channels, F_l=skip, F_int=skip // 2)

        self.unpool = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2, output_padding=pad)
        self.dropout = nn.Dropout2d(0.3)
        self.conv = ResBlock2d(out_channels + skip, out_channels)

    def forward(self, x, skip):
        x = self.unpool(x)
        skip = self.attn(x, skip)
        x = torch.cat([x, skip], dim=1)
        x = self.dropout(x)
        x = self.conv(x)
        return x

class UNet(nn.Module):
    def __init__(self, in_channels, num_filters, num_classes):
        super(UNet, self).__init__()

        self.down1 = Encode(in_channels, num_filters)
        self.down2 = Encode(num_filters, num_filters*2)
        self.down3 = Encode(num_filters*2, num_filters*4)
        self.down4 = Encode(num_filters*4, num_filters*8)

        self.bridge = DoubleConv(num_filters*8, num_filters*16)

        self.up1 = Decode(num_filters*16, num_filters*8, num_filters*8, (0 , 0))
        self.up2 = Decode(num_filters*8, num_filters*4, num_filters*4, (0 , 1))
        self.up3 = Decode(num_filters*4, num_filters*2, num_filters*2, (1 , 0))
        self.up4 = Decode(num_filters*2, num_filters, num_filters, (0 , 1))

        self.out_conv = nn.Conv2d(num_filters, num_classes, kernel_size=1)

    def forward(self, x):
        x1, x = self.down1(x)
        x2, x = self.down2(x)
        x3, x = self.down3(x)
        x4, x = self.down4(x)

        x = self.bridge(x)

        x = self.up1(x, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)

        return self.out_conv(x)

class MyModel(nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()
        self.models = nn.ModuleList(UNet(6, 32, 2) for _ in range(5))

    def forward(self, x):
        return sum(model(x) for model in self.models) / len(self.models)
"""
# Write code to file
with open('submission_model.py', 'w',encoding="utf-8") as f:
    f.write(model_code)
print("submission_model.py file has been generated.")

# %%
# Save the parameters of the model
torch.save(model.state_dict(), 'submission_dic.pth')
print("submission_dic.pth file has been saved.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3264281999.py in <cell line: 0>()
#       1 # Save the parameters of the model
# ----> 2 torch.save(model.state_dict(), 'submission_dic.pth')
#       3 print("submission_dic.pth file has been saved.")
#
# NameError: name 'model' is not defined

# %%
# This block mainly specifies the submission format of this question.
import zipfile
import os

# Define the files to zip and the zip file name.
files_to_zip = ['submission_model.py', 'submission_dic.pth']
zip_filename = 'submission.zip'

# Create a zip file
with zipfile.ZipFile(zip_filename, 'w') as zipf:
    for file in files_to_zip:
        # Add the file to the zip fil
        zipf.write(file, os.path.basename(file))

print(f'{zip_filename} Created successfully!')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3987598928.py in <cell line: 0>()
#      11     for file in files_to_zip:
#      12         # Add the file to the zip fil
# ---> 13         zipf.write(file, os.path.basename(file))
#      14
#      15 print(f'{zip_filename} Created successfully!')
#
# /usr/lib/python3.11/zipfile.py in write(self, filename, arcname, compress_type, compresslevel)
#    1794             )
#    1795
# -> 1796         zinfo = ZipInfo.from_file(filename, arcname,
#    1797                                   strict_timestamps=self._strict_timestamps)
#    1798
#
# /usr/lib/python3.11/zipfile.py in from_file(cls, filename, arcname, strict_timestamps)
#     533         if isinstance(filename, os.PathLike):
#     534             filename = os.fspath(filename)
# --> 535         st = os.stat(filename)
#     536         isdir = stat.S_ISDIR(st.st_mode)
#     537         mtime = time.localtime(st.st_mtime)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'submission_dic.pth'
